# %%
import read_l
import read_mat
import merge_mat_l

# %%
l_files = ["data/045-025/l_045_025_A", "data/045-025/l_044_019_B"]
mat_files = ["data/045-025/mat_045_025_mt_A", "data/045-025/mat_044_019_mt_B"]

l_df = read_l.concatenate_files(l_files)
mat_df = read_mat.concatenate_files(mat_files)

merged_df = merge_mat_l.merge_files(l_df, mat_df)
merged_df
# Out:
#         cycle  layers  convection variable 1  convection variable 2  \
# 0           1     145                      0                      0
# 1           1     145                      0                      0
# 2           1     145                      0                      0
# 3           1     145                      0                      0
# 4           1     145                      0                      0
# ...       ...     ...                    ...                    ...
# 457451    292     183                      0                      0
# 457452    292     183                      0                      0
# 457453    292     183                      0                      0
# 457454    292     183                      0                      0
# 457455    292     183                      0                      0
#
#         convection variable 3  convection variable 4        time_x  \
# 0                           0                      0  1.626370e+00
# ...

# %%
l_df
# Out:
#         cycle  layers  convection variable 1  convection variable 2  \
# 0           1     145                      0                      0
# 1           1     145                      0                      0
# 2           1     145                      0                      0
# 3           1     145                      0                      0
# 4           1     145                      0                      0
# ...       ...     ...                    ...                    ...
# 457451    292     183                      0                      0
# 457452    292     183                      0                      0
# 457453    292     183                      0                      0
# 457454    292     183                      0                      0
# 457455    292     183                      0                      0
#
#         convection variable 3  convection variable 4          time  \
# 0                           0                      0  1.626370e+00
# ...

# %%
mat_df
# Out:
#      cycle      Macc      Menv       Mej    Yenv     Yej     Zenv      Zej  \
# 0      1.0  0.000150  0.000169  0.000111  0.2621  0.2643  0.08473  0.08844
# 1      2.0  0.000526  0.000655  0.000620  0.2665  0.2677  0.13280  0.13990
# 2      3.0  0.000645  0.000762  0.000739  0.2508  0.2520  0.13270  0.13960
# 3      4.0  0.000686  0.000790  0.000767  0.2507  0.2521  0.12610  0.13290
# 4      5.0  0.000699  0.000803  0.000780  0.2511  0.2526  0.12440  0.13100
# ..     ...       ...       ...       ...     ...     ...      ...      ...
# 284  285.0  0.000605  0.000699  0.000712  0.2429  0.2392  0.15360  0.17600
# 285  286.0  0.000024  0.000000  0.000009  0.0000  0.2778  0.00000  0.02719
# 286  287.0  0.000605  0.000716  0.000728  0.2429  0.2393  0.15400  0.17590
# 287  288.0  0.000616  0.000708  0.000720  0.2444  0.2407  0.14860  0.17080
# 288  289.0  0.000628  0.000724  0.000736  0.2435  0.2399  0.15160  0.17370
#
# ...

# %%
mat_df["Mwd"]
# Out:
# 0      0.450486
# 1      0.450393
# 2      0.450299
# 3      0.450217
# 4      0.450136
#          ...
# 284    0.425135
# 285    0.425149
# 286    0.425026
# 287    0.424922
# 288    0.424814
# Name: Mwd, Length: 289, dtype: float64
