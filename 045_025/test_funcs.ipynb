# %%
import read_l
import read_mat
import merge_mat_l
import demarcator_funcs
import system_functions

# %%
# Read data from the file
data_lst = ["data/045-025/l_045_025_A", "data/045-025/l_044_019_B"]
df = read_l.concatenate_files(data_lst)

# %%
# Test draw function
cycles = [20, 100, 280]
demarcator = demarcator_funcs.demarcate_decay_phases
fig = system_functions.draw_cycles(df, cycles, demarcator)
