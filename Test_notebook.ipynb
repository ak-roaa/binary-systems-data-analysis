# %%
import read_system
# Out:
# /Users/my-mac/Desktop/read_system.py:18: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_name, sep="\s+", header=None)

# %%
# Read data from the files
data_lst = ["l_045_025_A", "l_044_019_B"]
binary_system = read_system.concatenate_files(data_lst)
# Out:
# /Users/my-mac/Desktop/read_system.py:18: DtypeWarning: Columns (8,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, sep="\s+", header=None)

# %%
cycles_list = [5, 100, 280]
read_system.draw_cycles(binary_system, cycles_list)
